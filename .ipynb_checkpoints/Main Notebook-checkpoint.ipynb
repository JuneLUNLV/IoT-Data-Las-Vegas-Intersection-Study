# %%
import pandas as pd
import gmaps
import gmaps.datasets

# %%
df = pd.read_csv("cleaned_intersection_fillna_column_mean.csv")
gmaps.configure(api_key='AIzaSyD21_CW-8IQ6xM7iWmavLVV2e-A0IfbOaA') 
figure_layout = {
    'width': '100px',
    'height': '100px',
    'padding': '1px'
}

# %%
uncleaned_df = pd.read_csv("intersection.csv")

# %%
uncleaned_df.columns
# Out:
# Index(['OBJECTID', 'Name', 'LOCATION_D', 'STREET_FRO', 'STREET_TO', 'LATITUDE',
#        'LONGITUDE', 'LAT_DECIMAL', 'LON_DECIMAL', 'ROUTE_NAME', 'StationType',
#        'ROUTE_ID', 'GlobalID', 'Visible', 'AADT_2007', 'AADT_2008',
#        'AADT_2009', 'AADT_2010', 'AADT_2011', 'AADT_2012', 'AADT_2013',
#        'AADT_2014', 'AADT_2015', 'AADT_2016', 'AADT_2017', 'AADT_2018',
#        'AADT_2019', 'Shape', 'AADT_2020', 'HourlyLabel', 'HourlyLink',
#        'ATRLabel', 'ATRLink', 'WeeklyLabel', 'WeeklyLink', 'PermanentDivider',
#        'JanLabel', 'FebLabel', 'MarLabel', 'AprLabel', 'MayLabel', 'JunLabel',
#        'JulLabel', 'AugLabel', 'SepLabel', 'OctLabel', 'NovLabel', 'DecLabel',
#        'JanLink', 'FebLink', 'MarLink', 'AprLink', 'MayLink', 'JunLink',
#        'JulLink', 'AugLink', 'SepLink', 'OctLink', 'NovLink', 'DecLink',
#        'MonthlyLabel'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'OBJECTID', 'Name', 'LAT_DECIMAL', 'LON_DECIMAL',
#        'AADT_2007', 'AADT_2008', 'AADT_2009', 'AADT_2010', 'AADT_2011',
#        'AADT_2012', 'AADT_2013', 'AADT_2014', 'AADT_2015', 'AADT_2016',
#        'AADT_2017', 'AADT_2018', 'AADT_2019', 'AADT_2020'],
#       dtype='object')

# %%
df
# Out:
#       Unnamed: 0  OBJECTID   Name  LAT_DECIMAL  LON_DECIMAL     AADT_2007  \
# 0              0      3830  31120        36.33      -114.92   26000.00000
# 1              1      3832  31210        36.15      -115.17  264000.00000
# 2              2      3833  31230        36.21      -115.13  118000.00000
# 3              3      3834  31250        36.02      -115.11  128000.00000
# 4              4      3835  32120        36.32      -115.31   11000.00000
# ...          ...       ...    ...          ...          ...           ...
# 1260        1260      8438  37216        35.97      -114.90   22593.11828
# 1261        1261      8439  37219        35.95      -114.90   22593.11828
# 1262        1262      8442  37222        35.97      -114.91   22593.11828
# 1263        1263      8444  37225        35.97      -114.91   22593.11828
# 1264        1264      8447  31183        36.02      -115.14   22593.11828
#
#           AADT_2008      AADT_2009      AADT_2010      AADT_2011  \
# 0      24000.000000   24000.000000   25000.000000   27000.000000
# 1     263000.000000  233000.000000  254000.000000  260000.000000
# 2     115000.000000  112000.000000  125000.000000  125000.000000
# 3     126000.000000  124000.000000  122000.000000  121000.000000
# 4      12000.000000   12300.000000   12400.000000   12500.000000
# ...             ...            ...            ...            ...
# 1260   21855.824494   21287.765152   22706.720484   22491.016097
# 1261   21855.824494   21287.765152   22706.720484   22491.016097
# 1262   21855.824494   21287.765152   22706.720484   22491.016097
# 1263   21855.824494   21287.765152   22706.720484   22491.016097
# 1264   21855.824494   21287.765152   22706.720484   22491.016097
#
#           AADT_2012      AADT_2013      AADT_2014      AADT_2015  \
# 0      26000.000000   25000.000000   24500.000000   27000.000000
# 1     260000.000000  261000.000000  260000.000000  260000.000000
# 2     126000.000000  126000.000000  132000.000000  142000.000000
# 3     121000.000000  122000.000000  128000.000000  135000.000000
# 4      12200.000000   12300.000000   12500.000000   13300.000000
# ...             ...            ...            ...            ...
# 1260   22239.751244   21396.430595   21439.325946   21950.774775
# 1261   22239.751244   21396.430595   21439.325946   21950.774775
# 1262   22239.751244   21396.430595   21439.325946   21950.774775
# 1263   22239.751244   21396.430595   21439.325946   21950.774775
# 1264   22239.751244   21396.430595   21439.325946   21950.774775
#
#           AADT_2016      AADT_2017      AADT_2018  AADT_2019  AADT_2020
# 0      29000.000000   30000.000000   30500.000000      31500      28900
# 1     260000.000000  278000.000000  281000.000000     288000     201000
# 2     145000.000000  140000.000000  131000.000000     148000     133000
# 3     139000.000000  144000.000000  146000.000000     148000     127000
# 4      14200.000000   14500.000000   14500.000000      15300      20900
# ...             ...            ...            ...        ...        ...
# 1260   22628.258929   21953.236715   22209.822452      35500      35000
# 1261   22628.258929   21953.236715   22209.822452       4900       3650
# 1262   22628.258929   21953.236715   22209.822452        670        390
# 1263   22628.258929   21953.236715   22209.822452       1850        390
# 1264   22628.258929   21953.236715   11500.000000       9950       9000
#
# [1265 rows x 19 columns]

# %%
las_vegas_intersection_location = df[['LAT_DECIMAL','LON_DECIMAL']]

# %%
las_vegas_intersection_location
# Out:
#       LAT_DECIMAL  LON_DECIMAL
# 0           36.33      -114.92
# 1           36.15      -115.17
# 2           36.21      -115.13
# 3           36.02      -115.11
# 4           36.32      -115.31
# ...           ...          ...
# 1260        35.97      -114.90
# 1261        35.95      -114.90
# 1262        35.97      -114.91
# 1263        35.97      -114.91
# 1264        36.02      -115.14
#
# [1265 rows x 2 columns]

# %%
info_box_template = """
<dl>
<dt>ID</dt><dd>{}</dd>
<dt>Latitude</dt><dd>{}</dd>
<dt>Longtitude</dt><dd>{}</dd>
<dt>Location</dt><dd>{}</dd>
</dl>
"""

intersection_info = []
for index, row in df.iterrows():
    intersection_info.append(info_box_template.format(row['OBJECTID'],row['LAT_DECIMAL'],row['LON_DECIMAL'],uncleaned_df.iloc[index]['LOCATION_D']))

# %%
intersection_layer = gmaps.symbol_layer(
    las_vegas_intersection_location, fill_color='#1c9e77', stroke_color='#1c9e77', scale=2 ,info_box_content=intersection_info
)
fig = gmaps.figure()
fig.add_layer(intersection_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'OBJECTID', 'Name', 'LAT_DECIMAL', 'LON_DECIMAL',
#        'AADT_2007', 'AADT_2008', 'AADT_2009', 'AADT_2010', 'AADT_2011',
#        'AADT_2012', 'AADT_2013', 'AADT_2014', 'AADT_2015', 'AADT_2016',
#        'AADT_2017', 'AADT_2018', 'AADT_2019', 'AADT_2020'],
#       dtype='object')

# %%
input_df = df[['AADT_2007','AADT_2008', 'AADT_2009', 'AADT_2010', 'AADT_2011', 'AADT_2012','AADT_2013', 'AADT_2014', 'AADT_2015', 'AADT_2016', 'AADT_2017','AADT_2018', 'AADT_2019', 'AADT_2020']]

# %%
input_df
# Out:
#          AADT_2007      AADT_2008      AADT_2009      AADT_2010  \
# 0      26000.00000   24000.000000   24000.000000   25000.000000
# 1     264000.00000  263000.000000  233000.000000  254000.000000
# 2     118000.00000  115000.000000  112000.000000  125000.000000
# 3     128000.00000  126000.000000  124000.000000  122000.000000
# 4      11000.00000   12000.000000   12300.000000   12400.000000
# ...            ...            ...            ...            ...
# 1260   22593.11828   21855.824494   21287.765152   22706.720484
# 1261   22593.11828   21855.824494   21287.765152   22706.720484
# 1262   22593.11828   21855.824494   21287.765152   22706.720484
# 1263   22593.11828   21855.824494   21287.765152   22706.720484
# 1264   22593.11828   21855.824494   21287.765152   22706.720484
#
#           AADT_2011      AADT_2012      AADT_2013      AADT_2014  \
# 0      27000.000000   26000.000000   25000.000000   24500.000000
# 1     260000.000000  260000.000000  261000.000000  260000.000000
# 2     125000.000000  126000.000000  126000.000000  132000.000000
# 3     121000.000000  121000.000000  122000.000000  128000.000000
# 4      12500.000000   12200.000000   12300.000000   12500.000000
# ...             ...            ...            ...            ...
# 1260   22491.016097   22239.751244   21396.430595   21439.325946
# 1261   22491.016097   22239.751244   21396.430595   21439.325946
# 1262   22491.016097   22239.751244   21396.430595   21439.325946
# 1263   22491.016097   22239.751244   21396.430595   21439.325946
# 1264   22491.016097   22239.751244   21396.430595   21439.325946
#
#           AADT_2015      AADT_2016      AADT_2017      AADT_2018  AADT_2019  \
# 0      27000.000000   29000.000000   30000.000000   30500.000000      31500
# 1     260000.000000  260000.000000  278000.000000  281000.000000     288000
# 2     142000.000000  145000.000000  140000.000000  131000.000000     148000
# 3     135000.000000  139000.000000  144000.000000  146000.000000     148000
# 4      13300.000000   14200.000000   14500.000000   14500.000000      15300
# ...             ...            ...            ...            ...        ...
# 1260   21950.774775   22628.258929   21953.236715   22209.822452      35500
# 1261   21950.774775   22628.258929   21953.236715   22209.822452       4900
# 1262   21950.774775   22628.258929   21953.236715   22209.822452        670
# 1263   21950.774775   22628.258929   21953.236715   22209.822452       1850
# 1264   21950.774775   22628.258929   21953.236715   11500.000000       9950
#
#       AADT_2020
# 0         28900
# 1        201000
# 2        133000
# 3        127000
# 4         20900
# ...         ...
# 1260      35000
# 1261       3650
# 1262        390
# 1263        390
# 1264       9000
#
# [1265 rows x 14 columns]

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(5,algorithm="elkan")

# %%
kmeans.fit(input_df)
# Out:
# KMeans(algorithm='elkan', n_clusters=5)

# %%
identified_clusters = kmeans.fit_predict(input_df)

# %%
identified_clusters
# Out:
# array([4, 3, 1, ..., 4, 4, 4])

# %%
popularity_df = pd.concat([las_vegas_intersection_location,pd.DataFrame(identified_clusters)],axis=1)

# %%
popularity_df.columns  = ['LAT_DECIMAL', 'LON_DECIMAL', 'POPULARITY_CLUSTER']

# %%
popularity_cluter_0_df = las_vegas_intersection_location[popularity_df['POPULARITY_CLUSTER'] == 0]
popularity_cluter_1_df = las_vegas_intersection_location[popularity_df['POPULARITY_CLUSTER'] == 1]
popularity_cluter_2_df = las_vegas_intersection_location[popularity_df['POPULARITY_CLUSTER'] == 2]
popularity_cluter_3_df = las_vegas_intersection_location[popularity_df['POPULARITY_CLUSTER'] == 3]
popularity_cluter_4_df = las_vegas_intersection_location[popularity_df['POPULARITY_CLUSTER'] == 4]

# %%
intersection_layer_cluter_0 = gmaps.symbol_layer(
    popularity_cluter_0_df, fill_color='#619cff', stroke_color='#619cff', scale=2
)

intersection_layer_cluter_1 = gmaps.symbol_layer(
    popularity_cluter_1_df, fill_color='#1c9e77', stroke_color='#1c9e77', scale=2
)

intersection_layer_cluter_2 = gmaps.symbol_layer(
    popularity_cluter_2_df, fill_color='#f8766d', stroke_color='#f8766d', scale=2
)

fig = gmaps.figure()
fig.add_layer(intersection_layer_cluter_0)
fig.add_layer(intersection_layer_cluter_1)
fig.add_layer(intersection_layer_cluter_2)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
popularity_cluter_0_df
# Out:
#       LAT_DECIMAL  LON_DECIMAL
# 4           36.32      -115.31
# 10          36.10      -114.90
# 12          36.01      -114.78
# 14          36.20      -115.22
# 19          36.23      -115.07
# ...           ...          ...
# 1259        35.95      -114.90
# 1261        35.95      -114.90
# 1262        35.97      -114.91
# 1263        35.97      -114.91
# 1264        36.02      -115.14
#
# [957 rows x 2 columns]

# %%
popularity_df = pd.concat([df,pd.DataFrame(identified_clusters)],axis=1)

# %%
popularity_df.columns = [   'OBJECTID',        'Name', 'LAT_DECIMAL', 'LON_DECIMAL',
         'AADT_2007',   'AADT_2008',   'AADT_2009',   'AADT_2010',
         'AADT_2011',   'AADT_2012',   'AADT_2013',   'AADT_2014',
         'AADT_2015',   'AADT_2016',   'AADT_2017',   'AADT_2018',
         'AADT_2019',   'AADT_2020',           'POPULARITY_CLUSTER']

# %%
popularity_df[popularity_df['POPULARITY_CLUSTER'] == 0]
# Out:
#       OBJECTID   Name  LAT_DECIMAL  LON_DECIMAL  AADT_2007  AADT_2008  \
# 4         3835  32120        36.32      -115.31    11000.0    12000.0
# 10        3844  33200        36.10      -114.90     2700.0     2500.0
# 12        3846  35220        36.01      -114.78    13000.0    13000.0
# 14        3848  35240        36.20      -115.22    17000.0    16000.0
# 19        3854  35330        36.23      -115.07        0.0    13000.0
# ...        ...    ...          ...          ...        ...        ...
# 1259      8437  37215        35.95      -114.90      195.0      195.0
# 1261      8439  37219        35.95      -114.90     4275.0     4275.0
# 1262      8442  37222        35.97      -114.91      530.0      530.0
# 1263      8444  37225        35.97      -114.91     1120.0     1120.0
# 1264      8447  31183        36.02      -115.14    10150.0    10150.0
#
#       AADT_2009  AADT_2010  AADT_2011  AADT_2012  AADT_2013  AADT_2014  \
# 4       12300.0    12400.0    12500.0    12200.0    12300.0    12500.0
# 10       2500.0     2300.0     2200.0     2200.0     2100.0     2150.0
# 12      13400.0    13700.0    16700.0    16400.0    16600.0    16800.0
# 14      15500.0    15500.0    14300.0    14000.0    13400.0    13900.0
# 19      12000.0    10000.0     9700.0     9500.0     8800.0     8700.0
# ...         ...        ...        ...        ...        ...        ...
# 1259      195.0      195.0      195.0      195.0      195.0      195.0
# 1261     4275.0     4275.0     4275.0     4275.0     4275.0     4275.0
# 1262      530.0      530.0      530.0      530.0      530.0      530.0
# 1263     1120.0     1120.0     1120.0     1120.0     1120.0     1120.0
# 1264    10150.0    10150.0    10150.0    10150.0    10150.0    10150.0
#
#       AADT_2015  AADT_2016  AADT_2017  AADT_2018  AADT_2019  AADT_2020  \
# 4       13300.0    14200.0    14500.0    14500.0    15300.0    20900.0
# 10       2050.0     2100.0     2400.0     2400.0     2500.0     2500.0
# 12      18300.0    19800.0    20000.0    15400.0     5100.0     3350.0
# 14      14600.0    14000.0    15100.0    15400.0    15550.0    11900.0
# 19       9500.0     8500.0     8700.0     8400.0     8950.0    10100.0
# ...         ...        ...        ...        ...        ...        ...
# 1259      195.0      195.0      195.0      195.0      190.0      200.0
# 1261     4275.0     4275.0     4275.0     4275.0     4900.0     3650.0
# 1262      530.0      530.0      530.0      530.0      670.0      390.0
# 1263     1120.0     1120.0     1120.0     1120.0     1850.0      390.0
# 1264    10150.0    10150.0    10150.0    11500.0     9950.0     9000.0
#
#       POPULARITY_CLUSTER
# 4                      0
# 10                     0
# 12                     0
# 14                     0
# 19                     0
# ...                  ...
# 1259                   0
# 1261                   0
# 1262                   0
# 1263                   0
# 1264                   0
#
# [957 rows x 19 columns]

# %%
print(popularity_df[popularity_df['POPULARITY_CLUSTER'] == 1].shape)
popularity_df[popularity_df['POPULARITY_CLUSTER'] == 1]
# Out:
# (40, 3)
#       LAT_DECIMAL  LON_DECIMAL  POPULARITY_CLUSTER
# 1           36.15      -115.17                   1
# 2           36.21      -115.13                   1
# 3           36.02      -115.11                   1
# 5           36.17      -115.22                   1
# 20          36.03      -115.18                   1
# 22          36.03      -115.04                   1
# 30          36.09      -115.07                   1
# 311         36.03      -115.13                   1
# 312         36.06      -115.16                   1
# 313         36.06      -115.15                   1
# 387         36.19      -115.14                   1
# 412         36.02      -115.09                   1
# 413         36.03      -115.06                   1
# 417         36.18      -115.15                   1
# 438         36.07      -115.19                   1
# 463         36.05      -115.14                   1
# 475         36.13      -115.18                   1
# 487         36.05      -115.18                   1
# 494         36.09      -115.18                   1
# 523         36.03      -115.07                   1
# 533         36.12      -115.18                   1
# 574         36.17      -115.16                   1
# 578         36.15      -115.09                   1
# 581         36.19      -115.24                   1
# 605         36.18      -115.15                   1
# 606         36.18      -115.18                   1
# 693         36.21      -115.24                   1
# 694         36.17      -115.23                   1
# 772         36.13      -115.09                   1
# 774         36.11      -115.08                   1
# 793         36.11      -115.18                   1
# 811         36.17      -115.14                   1
# 813         36.18      -115.17                   1
# 817         36.23      -115.25                   1
# 847         36.08      -115.18                   1
# 870         36.17      -115.12                   1
# 871         36.17      -115.10                   1
# 882         36.25      -115.25                   1
# 992         36.17      -115.20                   1
# 1115        36.05      -115.02                   1

# %%
popularity_df[popularity_df['POPULARITY_CLUSTER'] == 2]
# Out:
#       OBJECTID   Name  LAT_DECIMAL  LON_DECIMAL     AADT_2007     AADT_2008  \
# 0         3830  31120        36.33      -114.92  26000.000000  24000.000000
# 6         3837  32240        36.15      -115.07  42000.000000  42000.000000
# 7         3838  33120        36.07      -115.14  41000.000000  40000.000000
# 8         3840  33150        35.97      -114.88  35000.000000  34000.000000
# 9         3843  33190        36.22      -115.21  32000.000000  29000.000000
# ...        ...    ...          ...          ...           ...           ...
# 1134      8256  37022        36.00      -115.18  32500.000000  32500.000000
# 1203      8330  37186        36.11      -115.28  31750.000000  31750.000000
# 1212      8341  37203        35.98      -115.10  26325.000000  26325.000000
# 1215      8350  37015        36.12      -115.09  46833.333333  46833.333333
# 1260      8438  37216        35.97      -114.90  35250.000000  35250.000000
#
#          AADT_2009     AADT_2010     AADT_2011     AADT_2012     AADT_2013  \
# 0     24000.000000  25000.000000  27000.000000  26000.000000  25000.000000
# 6     42000.000000  41000.000000  41000.000000  38000.000000  38000.000000
# 7     38000.000000  37500.000000  38500.000000  40000.000000  39500.000000
# 8     34000.000000  34000.000000  36000.000000  36000.000000  36000.000000
# 9     27000.000000  26000.000000  27100.000000  27300.000000  25600.000000
# ...            ...           ...           ...           ...           ...
# 1134  32500.000000  32500.000000  32500.000000  32500.000000  32500.000000
# 1203  31750.000000  31750.000000  31750.000000  31750.000000  31750.000000
# 1212  26325.000000  26325.000000  26325.000000  26325.000000  26325.000000
# 1215  46833.333333  46833.333333  46833.333333  46833.333333  46833.333333
# 1260  35250.000000  35250.000000  35250.000000  35250.000000  35250.000000
#
#          AADT_2014     AADT_2015     AADT_2016     AADT_2017  AADT_2018  \
# 0     24500.000000  27000.000000  29000.000000  30000.000000    30500.0
# 6     41500.000000  39500.000000  39000.000000  41000.000000    42000.0
# 7     40500.000000  37500.000000  39000.000000  45000.000000    46000.0
# 8     37000.000000  39500.000000  41000.000000  41500.000000    38000.0
# 9     25100.000000  23000.000000  24100.000000  25600.000000    25800.0
# ...            ...           ...           ...           ...        ...
# 1134  32500.000000  32500.000000  32500.000000  33000.000000    30500.0
# 1203  31750.000000  31750.000000  31750.000000  33000.000000    36000.0
# 1212  26325.000000  26325.000000  26325.000000  30000.000000    29200.0
# 1215  46833.333333  46833.333333  46833.333333  46833.333333    49500.0
# 1260  35250.000000  35250.000000  35250.000000  35250.000000    35250.0
#
#       AADT_2019  AADT_2020  POPULARITY_CLUSTER
# 0       31500.0    28900.0                   2
# 6       42000.0    37000.0                   2
# 7       46000.0    35000.0                   2
# 8       26900.0    23200.0                   2
# 9       26300.0    22200.0                   2
# ...         ...        ...                 ...
# 1134    35000.0    31500.0                   2
# 1203    33500.0    24500.0                   2
# 1212    25000.0    21100.0                   2
# 1215    50000.0    41000.0                   2
# 1260    35500.0    35000.0                   2
#
# [266 rows x 19 columns]

# %%
# Out:
# (231, 2)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure(figsize = (17, 13), dpi = 80)
s = 50

plt.scatter(
    x=popularity_cluter_0_df['LON_DECIMAL'],
    y=popularity_cluter_0_df['LAT_DECIMAL'],
    s=s,
    color="#619cff"
)

plt.scatter(
    x=popularity_cluter_1_df['LON_DECIMAL'],
    y=popularity_cluter_1_df['LAT_DECIMAL'],
    s=s,
    color="#1c9e77"
)

plt.scatter(
    x=popularity_cluter_2_df['LON_DECIMAL'],
    y=popularity_cluter_2_df['LAT_DECIMAL'],
    s=s,
    color="#f8766d"
)

plt.scatter(
    x=popularity_cluter_3_df['LON_DECIMAL'],
    y=popularity_cluter_3_df['LAT_DECIMAL'],
    s=s,
    color="yellow"
)

plt.scatter(
    x=popularity_cluter_4_df['LON_DECIMAL'],
    y=popularity_cluter_4_df['LAT_DECIMAL'],
    s=s,
    color="orange"
)

plt.show()

# %%
from sklearn import svm

# %%
x= popularity_cluter_0_df[['LON_DECIMAL','LAT_DECIMAL']]
# Out:
#       LON_DECIMAL  LAT_DECIMAL
# 4         -115.31        36.32
# 9         -115.21        36.22
# 10        -114.90        36.10
# 12        -114.78        36.01
# 14        -115.22        36.20
# ...           ...          ...
# 1260      -114.90        35.97
# 1261      -114.90        35.95
# 1262      -114.91        35.97
# 1263      -114.91        35.97
# 1264      -115.14        36.02
#
# [994 rows x 2 columns]
